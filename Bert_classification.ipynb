# %% [markdown]
# <a href="https://colab.research.google.com/github/Jalajagr83/ML_Playook/blob/main/Bert_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install emoji
#!pip install simpletransformers
import pandas as pd
from sklearn.model_selection import train_test_split
import re
from simpletransformers.classification import ClassificationModel
import sklearn
import itertools
import emoji

# %%
df = pd.read_csv('https://raw.githubusercontent.com/priya-dwivedi/Deep-Learning/master/text_classification_with_BERT/train.csv')
df.head()
# Out:
#    id keyword  ...                                               text target
# 0   1     NaN  ...  Our Deeds are the Reason of this #earthquake M...      1
# 1   4     NaN  ...             Forest fire near La Ronge Sask. Canada      1
# 2   5     NaN  ...  All residents asked to 'shelter in place' are ...      1
# 3   6     NaN  ...  13,000 people receive #wildfires evacuation or...      1
# 4   7     NaN  ...  Just got sent this photo from Ruby #Alaska as ...      1
#
# [5 rows x 5 columns]

# %%
columns_drop = ['keyword','location']
df.drop(columns=columns_drop,inplace=True)
df.head()
# Out:
#    id                                               text  target
# 0   1  Our Deeds are the Reason of this #earthquake M...       1
# 1   4             Forest fire near La Ronge Sask. Canada       1
# 2   5  All residents asked to 'shelter in place' are ...       1
# 3   6  13,000 people receive #wildfires evacuation or...       1
# 4   7  Just got sent this photo from Ruby #Alaska as ...       1

# %%
fake_tweets = df[df.target == 0]
fake_tweets.shape
# Out:
# (4342, 3)

# %%
contractions = { 
"ain't": "am not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he would",
"he'd've": "he would have",
"he'll": "he will",
"he's": "he is",
"how'd": "how did",
"how'll": "how will",
"how's": "how is",
"i'd": "i would",
"i'll": "i will",
"i'm": "i am",
"i've": "i have",
"isn't": "is not",
"it'd": "it would",
"it'll": "it will",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"must've": "must have",
"mustn't": "must not",
"needn't": "need not",
"oughtn't": "ought not",
"shan't": "shall not",
"sha'n't": "shall not",
"she'd": "she would",
"she'll": "she will",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"that'd": "that would",
"that's": "that is",
"there'd": "there had",
"there's": "there is",
"they'd": "they would",
"they'll": "they will",
"they're": "they are",
"they've": "they have",
"wasn't": "was not",
"we'd": "we would",
"we'll": "we will",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what will",
"what're": "what are",
"what's": "what is",
"what've": "what have",
"where'd": "where did",
"where's": "where is",
"who'll": "who will",
"who's": "who is",
"won't": "will not",
"wouldn't": "would not",
"you'd": "you would",
"you'll": "you will",
"you're": "you are",
"thx"   : "thanks"
}

# %%
def remove_contractions(text):
    return contractions[text.lower()] if text.lower() in contractions.keys() else text

# %%
df['text']=df['text'].apply(remove_contractions)
df.head()
# Out:
#    id                                               text  target
# 0   1  Our Deeds are the Reason of this #earthquake M...       1
# 1   4             Forest fire near La Ronge Sask. Canada       1
# 2   5  All residents asked to 'shelter in place' are ...       1
# 3   6  13,000 people receive #wildfires evacuation or...       1
# 4   7  Just got sent this photo from Ruby #Alaska as ...       1

# %%
def clean_dataset(text):
    # Remove hashtag while keeping hashtag text
    text = re.sub(r'#','', text)
    # Remove HTML special entities (e.g. &amp;)
    text = re.sub(r'\&\w*;', '', text)
    # Remove tickers
    text = re.sub(r'\$\w*', '', text)
    # Remove hyperlinks
    text = re.sub(r'https?:\/\/.*\/\w*', '', text)
    # Remove whitespace (including new line characters)
    text = re.sub(r'\s\s+','', text)
    text = re.sub(r'[ ]{2, }',' ',text)
    # Remove URL, RT, mention(@)
    text=  re.sub(r'http(\S)+', '',text)
    text=  re.sub(r'http ...', '',text)
    text=  re.sub(r'(RT|rt)[ ]*@[ ]*[\S]+','',text)
    text=  re.sub(r'RT[ ]?@','',text)
    text = re.sub(r'@[\S]+','',text)
    # Remove words with 4 or fewer letters
    text = re.sub(r'\b\w{1,4}\b', '', text)
    #&, < and >
    text = re.sub(r'&amp;?', 'and',text)
    text = re.sub(r'&lt;','<',text)
    text = re.sub(r'&gt;','>',text)
    # Remove characters beyond Basic Multilingual Plane (BMP) of Unicode:
    text= ''.join(c for c in text if c <= '\uFFFF') 
    text = text.strip()
    # Remove misspelling words
    text = ''.join(''.join(s)[:2] for _, s in itertools.groupby(text))
    # Remove emoji
    text = emoji.demojize(text)
    text = text.replace(":"," ")
    text = ' '.join(text.split()) 
    text = re.sub("([^\x00-\x7F])+"," ",text)
    # Remove Mojibake (also extra spaces)
    text = ' '.join(re.sub("[^\u4e00-\u9fa5\u0030-\u0039\u0041-\u005a\u0061-\u007a]", " ", text).split())
    return text

# %%
df['text'] =df['text'].apply(clean_dataset)
df.head()
# Out:
#    id                                               text  target
# 0   1              Deeds Reason earthquake ALLAH Forgive       1
# 1   4                                Forest Ronge Canada       1
# 2   5  residents asked shelter place being notified o...       1
# 3   6  people receive wildfires evacuation orders Cal...       1
# 4   7          photo Alaska smoke wildfires pours school       1

# %%
X_train_clean, X_test_clean, y_train_clean, y_test_clean = train_test_split(df['text'], df['target'], test_size=0.20, random_state=42)

train_df_clean = pd.concat([X_train_clean, y_train_clean], axis=1)
print("Shape of training data set: ", train_df_clean.shape)
print("View of data set: ", train_df_clean.head())
# Out:
# Shape of training data set:  (6090, 2)
# View of data set:                                                     text  target
# 4996  Courageous honest analysis Atomic Hiroshima70 ...       1
# 3263          shame became engulfed flames boycottBears       0
# 4907  rescind medals honor given soldiers Massacre W...       1
# 2855  Worried about drought might affect Extreme Wea...       1
# 4716                           BlastPower PantherAttack       0

# %%
train_args = {
    'evaluate_during_training': True,
    'logging_steps': 100,
    'num_train_epochs': 2,
    'evaluate_during_training_steps': 100,
    'save_eval_checkpoints': False,
    'train_batch_size': 32,
    'eval_batch_size': 64,
    'overwrite_output_dir': True,
    'fp16': False,
    'wandb_project': "visualization-demo"
}

# %%
eval_df_clean = pd.concat([X_test_clean, y_test_clean], axis=1)
print("Shape of Eval data set: ", eval_df_clean.shape)
# Out:
# Shape of Eval data set:  (1523, 2)

# %%
model_BERT = ClassificationModel('bert', 'bert-base-cased', num_labels=2, use_cuda=True, cuda_device=0, args=train_args)
# Out:
# Downloading:   0%|          | 0.00/433 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/436M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/436k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]

# %%
model_BERT.train_model(train_df_clean, eval_df=eval_df_clean)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:449: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/6090 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/2 [00:00<?, ?it/s]
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter: ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
#                 Tracking run with wandb version 0.10.24<br/>
#                 Syncing run <strong style="color:#cdcd00">stellar-sea-1</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/jalaj83/visualization-demo" target="_blank">https://wandb.ai/jalaj83/visualization-demo</a><br/>
#                 Run page: <a href="https://wandb.ai/jalaj83/visualization-demo/runs/271yadvj" target="_blank">https://wandb.ai/jalaj83/visualization-demo/runs/271yadvj</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210405_073203-271yadvj</code><br/><br/>
# Running Epoch 0 of 2:   0%|          | 0/191 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:760: UserWarning: Using non-full backward hooks on a Module that does not return a single Tensor or a tuple of Tensors is deprecated and will be removed in future versions. This hook will be missing some of the grad_output. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using non-full backward hooks on a Module that does not return a "
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1029: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/1523 [00:00<?, ?it/s]
#   0%|          | 0/1523 [00:00<?, ?it/s]
# Running Epoch 1 of 2:   0%|          | 0/191 [00:00<?, ?it/s]
#   0%|          | 0/1523 [00:00<?, ?it/s]
#   0%|          | 0/1523 [00:00<?, ?it/s]
#   0%|          | 0/1523 [00:00<?, ?it/s]
# (382,
#  {'auprc': [0.7510892694812671,
#    0.8528257932859971,
#    0.8519244258305787,
#    0.8552957184181711,
#    0.8571096754963266],
#   'auroc': [0.8237007824041918,
#    0.8547607126612673,
#    0.8558396476889282,
#    0.85579381057991,
#    0.8557373956765029],
#   'eval_loss': [0.5451223130027453,
#    0.4553169409434001,
#    0.4719281954069932,
#    0.4871426373720169,
#    0.47408489013711613],
#   'fn': [162, 180, 155, 173, 191],
#   'fp': [175, 121, 158, 132, 112],
#   'global_step': [100, 191, 200, 300, 382],
#   'mcc': [0.5488246941919359,
#    0.5930311000852466,
#    0.5800525701556918,
#    0.5880872957443343,
#    0.590183757300275],
#   'tn': [699, 753, 716, 742, 762],
#   'tp': [487, 469, 494, 476, 458],
#   'train_loss': [0.4384186267852783,
#    0.46519652009010315,
#    0.26981475949287415,
#    0.6383641958236694,
#    0.306252658367157]})

# %%
result, model_outputs, wrong_predictions = model_BERT.eval_model(eval_df_clean, acc=sklearn.metrics.accuracy_score)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1029: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/1523 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/24 [00:00<?, ?it/s]
# Finishing last run (ID:271yadvj) before initializing another...
# <br/>Waiting for W&B process to finish, PID 274<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.03MB of 0.03MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210405_073203-271yadvj/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210405_073203-271yadvj/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Training loss</td><td>0.63836</td></tr><tr><td>lr</td><td>1e-05</td></tr><tr><td>global_step</td><td>382</td></tr><tr><td>_runtime</td><td>626</td></tr><tr><td>_timestamp</td><td>1617608549</td></tr><tr><td>_step</td><td>7</td></tr><tr><td>tp</td><td>458</td></tr><tr><td>tn</td><td>762</td></tr><tr><td>fp</td><td>112</td></tr><tr><td>fn</td><td>191</td></tr><tr><td>mcc</td><td>0.59018</td></tr><tr><td>train_loss</td><td>0.30625</td></tr><tr><td>eval_loss</td><td>0.47408</td></tr><tr><td>auroc</td><td>0.85574</td></tr><tr><td>auprc</td><td>0.85711</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Training loss</td><td>▄▁█</td></tr><tr><td>lr</td><td>█▅▁</td></tr><tr><td>global_step</td><td>▁▁▃▃▃▆▆█</td></tr><tr><td>_runtime</td><td>▁▁▃▄▄▆▆█</td></tr><tr><td>_timestamp</td><td>▁▁▃▄▄▆▆█</td></tr><tr><td>_step</td><td>▁▂▃▄▅▆▇█</td></tr><tr><td>tp</td><td>▇▃█▅▁</td></tr><tr><td>tn</td><td>▁▇▃▆█</td></tr><tr><td>fp</td><td>█▂▆▃▁</td></tr><tr><td>fn</td><td>▂▆▁▅█</td></tr><tr><td>mcc</td><td>▁█▆▇█</td></tr><tr><td>train_loss</td><td>▄▅▁█▂</td></tr><tr><td>eval_loss</td><td>█▁▂▃▂</td></tr><tr><td>auroc</td><td>▁████</td></tr><tr><td>auprc</td><td>▁████</td></tr></table><br/>
# Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">stellar-sea-1</strong>: <a href="https://wandb.ai/jalaj83/visualization-demo/runs/271yadvj" target="_blank">https://wandb.ai/jalaj83/visualization-demo/runs/271yadvj</a><br/>
# ...Successfully finished last run (ID:271yadvj). Initializing new run:<br/><br/>
#                 Tracking run with wandb version 0.10.24<br/>
#                 Syncing run <strong style="color:#cdcd00">jolly-sound-2</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/jalaj83/visualization-demo" target="_blank">https://wandb.ai/jalaj83/visualization-demo</a><br/>
#                 Run page: <a href="https://wandb.ai/jalaj83/visualization-demo/runs/tby16lon" target="_blank">https://wandb.ai/jalaj83/visualization-demo/runs/tby16lon</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210405_074837-tby16lon</code><br/><br/>

# %%
model_Roberta = ClassificationModel('roberta', 'roberta-base', num_labels=2, use_cuda=True, cuda_device=0, args=train_args)
model_Roberta.train_model(train_df_clean, eval_df=eval_df_clean)
result, model_outputs, wrong_predictions = model_Roberta.eval_model(eval_df_clean, acc=sklearn.metrics.accuracy_score)
# Out:
# Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/501M [00:00<?, ?B/s]
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.weight', 'classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:449: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/6090 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/2 [00:00<?, ?it/s]
# Finishing last run (ID:tby16lon) before initializing another...
# <br/>Waiting for W&B process to finish, PID 520<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.04MB of 0.04MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210405_074837-tby16lon/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210405_074837-tby16lon/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>8</td></tr><tr><td>_timestamp</td><td>1617608931</td></tr><tr><td>_step</td><td>2</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>▁▅█</td></tr><tr><td>_timestamp</td><td>▁▅█</td></tr><tr><td>_step</td><td>▁▅█</td></tr></table><br/>
# Synced 5 W&B file(s), 3 media file(s), 3 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">jolly-sound-2</strong>: <a href="https://wandb.ai/jalaj83/visualization-demo/runs/tby16lon" target="_blank">https://wandb.ai/jalaj83/visualization-demo/runs/tby16lon</a><br/>
# ...Successfully finished last run (ID:tby16lon). Initializing new run:<br/><br/>
#                 Tracking run with wandb version 0.10.24<br/>
#                 Syncing run <strong style="color:#cdcd00">brisk-rain-3</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/jalaj83/visualization-demo" target="_blank">https://wandb.ai/jalaj83/visualization-demo</a><br/>
#                 Run page: <a href="https://wandb.ai/jalaj83/visualization-demo/runs/1cduwxv4" target="_blank">https://wandb.ai/jalaj83/visualization-demo/runs/1cduwxv4</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210405_075212-1cduwxv4</code><br/><br/>
# Running Epoch 0 of 2:   0%|          | 0/191 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:760: UserWarning: Using non-full backward hooks on a Module that does not return a single Tensor or a tuple of Tensors is deprecated and will be removed in future versions. This hook will be missing some of the grad_output. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using non-full backward hooks on a Module that does not return a "
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1029: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/1523 [00:00<?, ?it/s]
#   0%|          | 0/1523 [00:00<?, ?it/s]
# Running Epoch 1 of 2:   0%|          | 0/191 [00:00<?, ?it/s]
#   0%|          | 0/1523 [00:00<?, ?it/s]
#   0%|          | 0/1523 [00:00<?, ?it/s]
#   0%|          | 0/1523 [00:00<?, ?it/s]
#   0%|          | 0/1523 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/24 [00:00<?, ?it/s]
# Finishing last run (ID:1cduwxv4) before initializing another...
# <br/>Waiting for W&B process to finish, PID 597<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.03MB of 0.03MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210405_075212-1cduwxv4/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210405_075212-1cduwxv4/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Training loss</td><td>0.47202</td></tr><tr><td>lr</td><td>1e-05</td></tr><tr><td>global_step</td><td>382</td></tr><tr><td>_runtime</td><td>655</td></tr><tr><td>_timestamp</td><td>1617609790</td></tr><tr><td>_step</td><td>7</td></tr><tr><td>tp</td><td>493</td></tr><tr><td>tn</td><td>740</td></tr><tr><td>fp</td><td>134</td></tr><tr><td>fn</td><td>156</td></tr><tr><td>mcc</td><td>0.60924</td></tr><tr><td>train_loss</td><td>0.56002</td></tr><tr><td>eval_loss</td><td>0.44773</td></tr><tr><td>auroc</td><td>0.86897</td></tr><tr><td>auprc</td><td>0.86934</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Training loss</td><td>█▁█</td></tr><tr><td>lr</td><td>█▅▁</td></tr><tr><td>global_step</td><td>▁▁▃▃▃▆▆█</td></tr><tr><td>_runtime</td><td>▁▁▃▄▄▆▆█</td></tr><tr><td>_timestamp</td><td>▁▁▃▄▄▆▆█</td></tr><tr><td>_step</td><td>▁▂▃▄▅▆▇█</td></tr><tr><td>tp</td><td>▄█▁▃█</td></tr><tr><td>tn</td><td>▁▄▆█▆</td></tr><tr><td>fp</td><td>█▅▃▁▃</td></tr><tr><td>fn</td><td>▅▁█▆▁</td></tr><tr><td>mcc</td><td>▁▆▄▇█</td></tr><tr><td>train_loss</td><td>▂█▁▂▃</td></tr><tr><td>eval_loss</td><td>█▆▁▃▂</td></tr><tr><td>auroc</td><td>▁▅▅██</td></tr><tr><td>auprc</td><td>▁▆▆██</td></tr></table><br/>
# Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">brisk-rain-3</strong>: <a href="https://wandb.ai/jalaj83/visualization-demo/runs/1cduwxv4" target="_blank">https://wandb.ai/jalaj83/visualization-demo/runs/1cduwxv4</a><br/>
# ...Successfully finished last run (ID:1cduwxv4). Initializing new run:<br/><br/>
#                 Tracking run with wandb version 0.10.24<br/>
#                 Syncing run <strong style="color:#cdcd00">lively-plant-4</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/jalaj83/visualization-demo" target="_blank">https://wandb.ai/jalaj83/visualization-demo</a><br/>
#                 Run page: <a href="https://wandb.ai/jalaj83/visualization-demo/runs/2ff960m5" target="_blank">https://wandb.ai/jalaj83/visualization-demo/runs/2ff960m5</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210405_080335-2ff960m5</code><br/><br/>

# %%
model_albert = ClassificationModel('albert', 'albert-base-v2', num_labels=2, use_cuda=True, cuda_device=0, args=train_args)
model_albert.train_model(train_df_clean, eval_df=eval_df_clean)
result, model_outputs, wrong_predictions = model_albert.eval_model(eval_df_clean, acc=sklearn.metrics.accuracy_score)
# Out:
# Downloading:   0%|          | 0.00/684 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/47.4M [00:00<?, ?B/s]
# Some weights of the model checkpoint at albert-base-v2 were not used when initializing AlbertForSequenceClassification: ['predictions.bias', 'predictions.LayerNorm.weight', 'predictions.LayerNorm.bias', 'predictions.dense.weight', 'predictions.dense.bias', 'predictions.decoder.weight', 'predictions.decoder.bias']
# - This IS expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of AlbertForSequenceClassification were not initialized from the model checkpoint at albert-base-v2 and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading:   0%|          | 0.00/760k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.31M [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:449: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/6090 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/2 [00:00<?, ?it/s]
# Finishing last run (ID:2ff960m5) before initializing another...
# <br/>Waiting for W&B process to finish, PID 709<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.04MB of 0.04MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210405_080335-2ff960m5/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210405_080335-2ff960m5/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>9</td></tr><tr><td>_timestamp</td><td>1617609827</td></tr><tr><td>_step</td><td>2</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>▁▅█</td></tr><tr><td>_timestamp</td><td>▁▅█</td></tr><tr><td>_step</td><td>▁▅█</td></tr></table><br/>
# Synced 5 W&B file(s), 3 media file(s), 3 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">lively-plant-4</strong>: <a href="https://wandb.ai/jalaj83/visualization-demo/runs/2ff960m5" target="_blank">https://wandb.ai/jalaj83/visualization-demo/runs/2ff960m5</a><br/>
# ...Successfully finished last run (ID:2ff960m5). Initializing new run:<br/><br/>
#                 Tracking run with wandb version 0.10.24<br/>
#                 Syncing run <strong style="color:#cdcd00">twilight-mountain-5</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/jalaj83/visualization-demo" target="_blank">https://wandb.ai/jalaj83/visualization-demo</a><br/>
#                 Run page: <a href="https://wandb.ai/jalaj83/visualization-demo/runs/d3jcwvlx" target="_blank">https://wandb.ai/jalaj83/visualization-demo/runs/d3jcwvlx</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210405_080646-d3jcwvlx</code><br/><br/>
# Running Epoch 0 of 2:   0%|          | 0/191 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:760: UserWarning: Using non-full backward hooks on a Module that does not return a single Tensor or a tuple of Tensors is deprecated and will be removed in future versions. This hook will be missing some of the grad_output. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using non-full backward hooks on a Module that does not return a "
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1029: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/1523 [00:00<?, ?it/s]
#   0%|          | 0/1523 [00:00<?, ?it/s]
# Running Epoch 1 of 2:   0%|          | 0/191 [00:00<?, ?it/s]
#   0%|          | 0/1523 [00:00<?, ?it/s]
#   0%|          | 0/1523 [00:00<?, ?it/s]
#   0%|          | 0/1523 [00:00<?, ?it/s]
#   0%|          | 0/1523 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/24 [00:00<?, ?it/s]
# Finishing last run (ID:d3jcwvlx) before initializing another...
# <br/>Waiting for W&B process to finish, PID 754<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210405_080646-d3jcwvlx/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210405_080646-d3jcwvlx/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Training loss</td><td>0.38022</td></tr><tr><td>lr</td><td>1e-05</td></tr><tr><td>global_step</td><td>382</td></tr><tr><td>_runtime</td><td>641</td></tr><tr><td>_timestamp</td><td>1617610651</td></tr><tr><td>_step</td><td>7</td></tr><tr><td>tp</td><td>441</td></tr><tr><td>tn</td><td>734</td></tr><tr><td>fp</td><td>140</td></tr><tr><td>fn</td><td>208</td></tr><tr><td>mcc</td><td>0.52869</td></tr><tr><td>train_loss</td><td>0.73001</td></tr><tr><td>eval_loss</td><td>0.49634</td></tr><tr><td>auroc</td><td>0.83541</td></tr><tr><td>auprc</td><td>0.82451</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Training loss</td><td>█▁▄</td></tr><tr><td>lr</td><td>█▅▁</td></tr><tr><td>global_step</td><td>▁▁▃▃▃▆▆█</td></tr><tr><td>_runtime</td><td>▁▁▃▄▄▆▆█</td></tr><tr><td>_timestamp</td><td>▁▁▃▄▄▆▆█</td></tr><tr><td>_step</td><td>▁▂▃▄▅▆▇█</td></tr><tr><td>tp</td><td>█▁▃▆▃</td></tr><tr><td>tn</td><td>▁██▅▇</td></tr><tr><td>fp</td><td>█▁▁▄▂</td></tr><tr><td>fn</td><td>▁█▆▃▆</td></tr><tr><td>mcc</td><td>▁▇█▆▇</td></tr><tr><td>train_loss</td><td>▆▆▁▃█</td></tr><tr><td>eval_loss</td><td>█▁▄▃▁</td></tr><tr><td>auroc</td><td>▁▇▇▆█</td></tr><tr><td>auprc</td><td>▁▇▆▇█</td></tr></table><br/>
# Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">twilight-mountain-5</strong>: <a href="https://wandb.ai/jalaj83/visualization-demo/runs/d3jcwvlx" target="_blank">https://wandb.ai/jalaj83/visualization-demo/runs/d3jcwvlx</a><br/>
# ...Successfully finished last run (ID:d3jcwvlx). Initializing new run:<br/><br/>
#                 Tracking run with wandb version 0.10.24<br/>
#                 Syncing run <strong style="color:#cdcd00">icy-donkey-6</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/jalaj83/visualization-demo" target="_blank">https://wandb.ai/jalaj83/visualization-demo</a><br/>
#                 Run page: <a href="https://wandb.ai/jalaj83/visualization-demo/runs/1za5c9d1" target="_blank">https://wandb.ai/jalaj83/visualization-demo/runs/1za5c9d1</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210405_081757-1za5c9d1</code><br/><br/>

# %%
test_df = pd.read_csv('https://raw.githubusercontent.com/priya-dwivedi/Deep-Learning/master/text_classification_with_BERT/test.csv')
test_df.head()
# Out:
#    id keyword location                                               text
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about #earthquake is different cities, s...
# 2   3     NaN      NaN  there is a forest fire at spot pond, geese are...
# 3   9     NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 4  11     NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan

# %%
## Drop columns for keyword and location
columns_todrop = ['keyword','location']
test_df.drop(columns=columns_todrop,inplace=True)
### Change contractions
test_df['text']=test_df['text'].apply(remove_contractions)
## Clean Data set
test_df['text'] =test_df['text'].apply(clean_dataset)
test_df.head()
# Out:
#    id                                              text
# 0   0                           happened terrible crash
# 1   2  Heard about earthquake different cities everyone
# 2   3   there forest geese fleeing across street cannot
# 3   9             Apocalypse lighting Spokane wildfires
# 4  11               Typhoon Soudelor kills China Taiwan

# %%
predictions, raw_outputs = model_Roberta.predict(xtest)
# Out:
#   0%|          | 0/3263 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_utils.py", line 103, in preprocess_data_multiprocessing
#     return_tensors="pt",
#   File "/usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py", line 2215, in __call__
#     "text input must of type `str` (single example), `List[str]` (batch or single pretokenized example) "
# AssertionError: text input must of type `str` (single example), `List[str]` (batch or single pretokenized example) or `List[List[str]]` (batch of pretokenized examples).
# """
#
# The above exception was the direct cause of the following exception:
#
# AssertionError                            Traceback (most recent call last)
# <ipython-input-35-9a7139a6827f> in <module>()
# ----> 1 predictions, raw_outputs = model_Roberta.predict(xtest)
#
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py in predict(self, to_predict, multi_label)
#    1447             else:
#    1448                 eval_dataset = self.load_and_cache_examples(
# -> 1449                     eval_examples, evaluate=True, multi_label=multi_label, no_cache=True
#    1450                 )
#    1451
#
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py in load_and_cache_examples(self, examples, evaluate, no_cache, multi_label, verbose, silent)
#    1300                 multi_label=multi_label,
#    1301                 output_mode=output_mode,
# -> 1302                 no_cache=no_cache,
#    1303             )
#    1304             return dataset
#
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_utils.py in __init__(self, data, tokenizer, args, mode, multi_label, output_mode, no_cache)
#     226     def __init__(self, data, tokenizer, args, mode, multi_label, output_mode, no_cache):
#     227         self.examples, self.labels = build_classification_dataset(
# --> 228             data, tokenizer, args, mode, multi_label, output_mode, no_cache
#     229         )
#     230
#
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_utils.py in build_classification_dataset(data, tokenizer, args, mode, multi_label, output_mode, no_cache)
#     202             with Pool(args.process_count) as p:
#     203                 examples = list(
# --> 204                     tqdm(p.imap(preprocess_data_multiprocessing, data), total=len(text_a), disable=args.silent)
#     205                 )
#     206
#
# /usr/local/lib/python3.7/dist-packages/tqdm/notebook.py in __iter__(self)
#     246     def __iter__(self):
#     247         try:
# --> 248             for obj in super(tqdm_notebook, self).__iter__():
#     249                 # return super(tqdm...) will not catch exception
#     250                 yield obj
#
# /usr/local/lib/python3.7/dist-packages/tqdm/std.py in __iter__(self)
#    1176
#    1177         try:
# -> 1178             for obj in iterable:
#    1179                 yield obj
#    1180                 # Update and possibly print the progressbar.
#
# /usr/lib/python3.7/multiprocessing/pool.py in next(self, timeout)
#     746         if success:
#     747             return value
# --> 748         raise value
#     749
#     750     __next__ = next                    # XXX
#
# /usr/lib/python3.7/multiprocessing/pool.py in worker()
#     119         job, i, func, args, kwds = task
#     120         try:
# --> 121             result = (True, func(*args, **kwds))
#     122         except Exception as e:
#     123             if wrap_exception and func is not _helper_reraises_exception:
#
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_utils.py in preprocess_data_multiprocessing()
#     101         truncation=True,
#     102         padding="max_length",
# --> 103         return_tensors="pt",
#     104     )
#     105
#
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py in __call__()
#    2213             )
#    2214         ), (
# -> 2215             "text input must of type `str` (single example), `List[str]` (batch or single pretokenized example) "
#    2216             "or `List[List[str]]` (batch of pretokenized examples)."
#    2217         )
#
# AssertionError: text input must of type `str` (single example), `List[str]` (batch or single pretokenized example) or `List[List[str]]` (batch of pretokenized examples).

# %%
test_df['target']=predictions
test_df.tail()

# %%
test_df['target'].value_counts()

# %%
test_tweet1 = "#COVID19 will spread across U.S. in coming weeks. We’ll get past it, but must focus on limiting the epidemic, and preserving lif"
test_tweet1 = remove_contractions(test_tweet1)
test_tweet1 = clean_dataset(test_tweet1)

# %%
predictions, _ = model_Roberta.predict([test_tweet1])
response_dict = {0: 'Fake', 1: 'Real'}
print("Prediction is: ", response_dict[predictions[0]])
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Prediction is:  Real

# %%
test_tweet2 = "BREAKING: Confirmed flooding on NYSE. The trading floor is flooded under more than 3 feet of water."
test_tweet2 = remove_contractions(test_tweet2)
test_tweet2 = clean_dataset(test_tweet2)

predictions, _ = model_Roberta.predict([test_tweet2])
response_dict = {0: 'Fake', 1: 'Real'}
print("Prediction is: ", response_dict[predictions[0]])
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Prediction is:  Real

# %%
test_tweet3 = "Everything is ABLAZE. Please run!!"
test_tweet3 = remove_contractions(test_tweet3)
test_tweet3 = clean_dataset(test_tweet3)
predictions, _ = model_Roberta.predict([test_tweet3])
response_dict = {0: 'Fake', 1: 'Real'}
print("Prediction is: ", response_dict[predictions[0]])
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Prediction is:  Fake
